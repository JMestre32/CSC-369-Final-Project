# %%
import pandas as pd
df = pd.read_csv("tmdb_5000_movies.csv")
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
import json

# %%
def extract_first_company_name(json_str):
    try:
        companies = json.loads(json_str)
        if companies:
            return companies[0]['name']
        else:
            return None
    except json.JSONDecodeError:
        return None

# Apply the function to the 'production_companies' column
df['first_company_name'] = df['production_companies'].apply(extract_first_company_name)

# Display the DataFrame with the new 'first_company_name' column
print(df[['production_companies', 'first_company_name']])
# Out:
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#             first_company_name
# 0      Ingenious Film Partners
# 1         Walt Disney Pictures
# 2            Columbia Pictures
# 3           Legendary Pictures
# 4         Walt Disney Pictures
# ...                        ...
# 4798         Columbia Pictures
# 4799                      None
# ...

# %%
def genre(json_str):
    try:
        companies = json.loads(json_str)
        if companies:
            return companies[0]['name']
        else:
            return None
    except json.JSONDecodeError:
        return None

# Apply the function to the 'production_companies' column
df['genre'] = df['genres'].apply(genre)

# Display the DataFrame with the new 'first_company_name' column
print(df[['genre', 'genres']])
# Out:
#             genre                                             genres
# 0          Action  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       Adventure  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2          Action  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3          Action  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4          Action  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 4798       Action  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       Comedy  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       Comedy  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801         None                                                 []
# 4802  Documentary                [{"id": 99, "name": "Documentary"}]
#
# [4803 rows x 2 columns]

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'first_company_name', 'genre'],
#       dtype='object')

# %%
#new = old.filter(['A','B','D'], axis=1)

df_new = df.filter(["budget", "original_title", "popularity", "first_company_name", "revenue", "vote_average", "vote_count", "genre"], axis=1)
df_new
# Out:
#          budget                            original_title  popularity  \
# 0     237000000                                    Avatar  150.437577
# 1     300000000  Pirates of the Caribbean: At World's End  139.082615
# 2     245000000                                   Spectre  107.376788
# 3     250000000                     The Dark Knight Rises  112.312950
# 4     260000000                               John Carter   43.926995
# ...         ...                                       ...         ...
# 4798     220000                               El Mariachi   14.269792
# 4799       9000                                 Newlyweds    0.642552
# 4800          0                 Signed, Sealed, Delivered    1.444476
# 4801          0                          Shanghai Calling    0.857008
# 4802          0                         My Date with Drew    1.929883
#
#             first_company_name     revenue  vote_average  vote_count  \
# ...

# %%
df_new['original_title'] = df_new['original_title'].str.replace('"', '')
df_new["first_company_name"] = df_new["first_company_name"].str.replace('"', '')
df_new["first_company_name"] = df_new["first_company_name"].fillna("N/A")
df_new["genre"] = df_new["genre"].fillna("N/A")

# %%
df_new["genre"].value_counts()
# Out:
# genre
# Drama              1207
# Comedy             1042
# Action              754
# Adventure           339
# Horror              300
# Crime               195
# Thriller            194
# Animation           123
# Fantasy             117
# Romance             106
# Science Fiction      96
# Documentary          89
# Family               56
# Mystery              41
# Music                34
# N/A                  28
# Western              27
# History              25
# War                  24
# TV Movie              4
# Foreign               2
# Name: count, dtype: int64

# %%
df_new.shape
# Out:
# (4803, 8)

# %%
print(df_new["first_company_name"].unique())
# Out:
# ['Ingenious Film Partners' 'Walt Disney Pictures' 'Columbia Pictures' ...
#  'Asylum Films' 'Front Street Pictures' 'rusty bear entertainment']

# %%
df_new.head()
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  300000000  Pirates of the Caribbean: At World's End  139.082615
# 2  245000000                                   Spectre  107.376788
# 3  250000000                     The Dark Knight Rises  112.312950
# 4  260000000                               John Carter   43.926995
#
#         first_company_name     revenue  vote_average  vote_count      genre
# 0  Ingenious Film Partners  2787965087           7.2       11800     Action
# 1     Walt Disney Pictures   961000000           6.9        4500  Adventure
# 2        Columbia Pictures   880674609           6.3        4466     Action
# 3       Legendary Pictures  1084939099           7.6        9106     Action
# 4     Walt Disney Pictures   284139100           6.1        2124     Action

# %%
data_blockbuster = {
    'Category': ['Not a Blockbuster', 'Blockbuster'],
    'Values': [3169, 4803 - 3169]
}
df_block = pd.DataFrame(data_blockbuster)
fig = px.pie(df_block, values='Values', names='Category', title='Pie Chart Example')
fig.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_new.to_csv("movie_try.csv", sep=',', index=False, encoding='utf-8')

# %%
data = pd.read_csv('output.txt', sep=":", header=None)
data.columns = ["category", "value"]
data
# Out:
#                                             category         value
# 0                                          Intercept  6.959496e+06
# 1                                             budget  1.616608e+00
# 2                                         popularity  2.955848e+05
# 3                                       vote_average -1.245153e+06
# 4                                         vote_count  6.732038e+04
# ...                                              ...           ...
# 1334                            companyVec_SKA Films -1.421499e+07
# 1335                 companyVec_Bungalow Productions -6.564860e+06
# 1336                          companyVec_HDNet Films  6.062477e+05
# 1337                 companyVec_Big Idea Productions  1.794906e+07
# 1338  Mean Squared Error (MSE) = 6.12802524303074E15           NaN
#
# [1339 rows x 2 columns]

# %%
split_data = data['category'].str.split('_', expand=True)
cleaned_company = split_data[1].where(split_data[1].notnull(), data['category'])
data["cleanedCompany"] = cleaned_company
data
# Out:
#                                             category         value  \
# 0                                          Intercept  6.959496e+06
# 1                                             budget  1.616608e+00
# 2                                         popularity  2.955848e+05
# 3                                       vote_average -1.245153e+06
# 4                                         vote_count  6.732038e+04
# ...                                              ...           ...
# 1334                            companyVec_SKA Films -1.421499e+07
# 1335                 companyVec_Bungalow Productions -6.564860e+06
# 1336                          companyVec_HDNet Films  6.062477e+05
# 1337                 companyVec_Big Idea Productions  1.794906e+07
# 1338  Mean Squared Error (MSE) = 6.12802524303074E15           NaN
#
#                                       cleanedCompany
# 0                                          Intercept
# 1                                             budget
# ...

# %%
data['isCompany'] = data['category'].str.startswith('companyVec').astype(int)
data['isGenre'] = data['category'].str.startswith('genreVec').astype(int)

# %%
data.head()
# Out:
#        category         value cleanedCompany  isCompany  isGenre
# 0     Intercept  6.959496e+06      Intercept          0        0
# 1        budget  1.616608e+00         budget          0        0
# 2    popularity  2.955848e+05     popularity          0        0
# 3  vote_average -1.245153e+06        average          0        0
# 4    vote_count  6.732038e+04          count          0        0

# %%
genre_df = data[data["isGenre"] == 1]
company_df = data[data["isCompany"] == 1]

# %%
sorted = genre_df.sort_values(by="value", ascending = False)
sorted_comp = company_df.sort_values(by = "value", ascending = False)

# %%
sorted.head(
)
# Out:
#                 category         value cleanedCompany  isCompany  isGenre
# 17       genreVec_Family  4.815023e+07         Family          0        1
# 12    genreVec_Animation  3.386264e+07      Animation          0        1
# 22      genreVec_History  1.725009e+07        History          0        1
# 14      genreVec_Romance  8.384360e+06        Romance          0        1
# 16  genreVec_Documentary  4.421994e+06    Documentary          0        1

# %%
sorted.tail()
# Out:
#              category         value cleanedCompany  isCompany  isGenre
# 7     genreVec_Action -1.884809e+07         Action          0        1
# 11  genreVec_Thriller -2.011864e+07       Thriller          0        1
# 10     genreVec_Crime -2.351187e+07          Crime          0        1
# 23       genreVec_War -3.872874e+07            War          0        1
# 21   genreVec_Western -4.916210e+07        Western          0        1

# %% [markdown]
# Get the values greater than 0, get the biggest values 100e6. Didn't do in scala because i couldn't figure out a way to filter the cpeffocoemts

# %%
df_highcoef = sorted[sorted.value>0]
df_highcoef_company = sorted_comp[sorted_comp.value > 100e6]

# %%
import plotly.express as px
px.bar(df_highcoef, x = "cleanedCompany", y = "value", title="Highest Correlation to Movie Success",
       labels ={ "cleanedCompany": "Genre",
       "value": "Revenue"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_compPop = pd.read_csv('output3.txt', sep=":", header=None)
df_compPop.columns = ["negligible", "compName", "popularity"]
df_compPop
# Out:
#   negligible                                           compName  popularity
# 0    Company            Black Bear Pictures, Average Popularity  145.364591
# 1    Company                 Marvel Studios, Average Popularity  134.390332
# 2    Company                   Gotham Group, Average Popularity  113.161483
# 3    Company       Lightstorm Entertainment, Average Popularity  101.741550
# 4    Company   Patalex IV Productions Limited, Average Popul...  101.250416
# 5    Company          Northern Lights Films, Average Popularity  100.876794
# 6    Company                  Shaw Brothers, Average Popularity   94.056131
# 7    Company               Estudios Picasso, Average Popularity   90.809408
# 8    Company                  1492 Pictures, Average Popularity   90.580988
# 9    Company    Stanley Kubrick Productions, Average Popularity   86.201184

# %%
def getCompanyName(line):
  a = line.split(",")
  return a[0]
df_compPop['companyName'] = df_compPop['compName'].apply(getCompanyName)

# %%
df_compPop
# Out:
#   negligible                                           compName  popularity  \
# 0    Company            Black Bear Pictures, Average Popularity  145.364591
# 1    Company                 Marvel Studios, Average Popularity  134.390332
# 2    Company                   Gotham Group, Average Popularity  113.161483
# 3    Company       Lightstorm Entertainment, Average Popularity  101.741550
# 4    Company   Patalex IV Productions Limited, Average Popul...  101.250416
# 5    Company          Northern Lights Films, Average Popularity  100.876794
# 6    Company                  Shaw Brothers, Average Popularity   94.056131
# 7    Company               Estudios Picasso, Average Popularity   90.809408
# 8    Company                  1492 Pictures, Average Popularity   90.580988
# 9    Company    Stanley Kubrick Productions, Average Popularity   86.201184
#
#                        companyName
# 0              Black Bear Pictures
# 1                   Marvel Studios
# ...

# %%
px.bar(df_compPop, x = "companyName", y = "popularity", title="Top 10 Most Popular Company Based on Average Popularity Score", color = "companyName",
       labels = {
           "companyName": "Company",
           "popularity": "Popularity Points"
       })
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_budjComp = pd.read_csv('budgetCompany.txt', sep=":", header=None)
df_budjComp.columns = ["negligible", "compName", "budget"]
df_budjComp["companyName"] = df_budjComp["compName"].apply(getCompanyName)
df_budjComp
# Out:
#   negligible                                           compName        budget  \
# 0    Company                 Marvel Studios, Average Popularity  1.750000e+08
# 1    Company             Mid Atlantic Films, Average Popularity  1.750000e+08
# 2    Company   Walt Disney Animation Studios, Average Popula...  1.550000e+08
# 3    Company   Patalex IV Productions Limited, Average Popul...  1.500000e+08
# 4    Company           DreamWorks Animation, Average Popularity  1.401429e+08
# 5    Company                      DC Comics, Average Popularity  1.396667e+08
# 6    Company                  WingNut Films, Average Popularity  1.323000e+08
# 7    Company      Pacific Data Images (PDI), Average Popularity  1.250000e+08
# 8    Company                  1492 Pictures, Average Popularity  1.112500e+08
# 9    Company                 One Race Films, Average Popularity  1.050000e+08
#
#                        companyName
# 0                   Marvel Studios
# 1               Mid Atlantic Films
# ...

# %%
px.bar(df_budjComp, x = "companyName", y = "budget", title="Top 10 Companies with the Highest Average Budget", color = "companyName",
       labels = {
           "companyName": "Company",
           "budget": "Budget (M)"
       })
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
